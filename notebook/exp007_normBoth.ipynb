# %%
import pandas as pd
import torch
from pathlib import Path
from hydra import initialize, compose
from hydra.core.global_hydra import GlobalHydra
from src.utils.metrics import event_detection_ap

from src.utils.post_process import post_process_for_seg
import jupyter_black
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import optuna


jupyter_black.load()
plt.style.use("ggplot")

EXP_NAME = "exp007_normBoth"
RUN_NAME = "single"
RESULT_DIR = Path("../output/train") / EXP_NAME / RUN_NAME


def load_config(result_dir: Path):
    # clear previous initialization
    GlobalHydra.instance().clear()

    # initialize hydra
    config_path = result_dir / ".hydra"
    initialize(config_path=config_path.as_posix())
    # load the config
    cfg = compose(config_name="config")

    return cfg
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
cfg = load_config(RESULT_DIR)
preds = np.load(RESULT_DIR / "preds_fold_0.npy")
labels = np.load(RESULT_DIR / "labels_fold_0.npy")
keys = np.load(RESULT_DIR / "keys_fold_0.npy")

gt_df = pd.read_csv(Path(cfg.dir.data_dir) / "train_events.csv")
gt_df = gt_df[gt_df["series_id"].isin(cfg.split.valid_series_ids)].dropna().reset_index(drop=True)
# Out:
# /tmp/ipykernel_2306/3616093721.py:31: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   initialize(config_path=config_path.as_posix())

# %%
def objective(trial: optuna.Trial):
    score_th = trial.suggest_float("score_th", 0.001, 0.1)
    distance = trial.suggest_int("distance", 1, 200)

    # pred_df: pl.DataFrame = post_process_for_seg(
    #     keys, preds[:, :, [1, 2]], score_th=score_th, distance=distance
    # )
    pred_df: pl.DataFrame = post_process_for_seg(keys, preds, score_th=score_th, distance=distance)
    score = event_detection_ap(gt_df, pred_df.to_pandas())

    return score


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print(study.best_params)
# Out:
# [I 2023-11-26 01:15:12,105] A new study created in memory with name: no-name-ac6de326-cacd-4049-aa44-35c54c756ade
# [I 2023-11-26 01:15:15,657] Trial 0 finished with value: 0.7289970930578697 and parameters: {'score_th': 0.09083814215095395, 'distance': 184}. Best is trial 0 with value: 0.7289970930578697.
# [I 2023-11-26 01:15:18,820] Trial 1 finished with value: 0.7383257082000806 and parameters: {'score_th': 0.06750408248881017, 'distance': 160}. Best is trial 1 with value: 0.7383257082000806.
# [I 2023-11-26 01:15:22,184] Trial 2 finished with value: 0.740755246089456 and parameters: {'score_th': 0.05600066663615076, 'distance': 176}. Best is trial 2 with value: 0.740755246089456.
# [I 2023-11-26 01:15:25,698] Trial 3 finished with value: 0.7487099794199149 and parameters: {'score_th': 0.05079300893370221, 'distance': 75}. Best is trial 3 with value: 0.7487099794199149.
# [I 2023-11-26 01:15:29,367] Trial 4 finished with value: 0.7451944500440097 and parameters: {'score_th': 0.01819365812678224, 'distance': 200}. Best is trial 3 with value: 0.7487099794199149.
# [I 2023-11-26 01:15:32,730] Trial 5 finished with value: 0.7385950989806094 and parameters: {'score_th': 0.0883413445897009, 'distance': 83}. Best is trial 3 with value: 0.7487099794199149.
# [I 2023-11-26 01:15:36,189] Trial 6 finished with value: 0.7488874449039309 and parameters: {'score_th': 0.0463615862148149, 'distance': 35}. Best is trial 6 with value: 0.7488874449039309.
. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:26,438] Trial 67 finished with value: 0.7578743276336135 and parameters: {'score_th': 0.00851475971041731, 'distance': 102}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:30,990] Trial 68 finished with value: 0.7588339246356746 and parameters: {'score_th': 0.0038975503151366803, 'distance': 88}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:34,752] Trial 69 finished with value: 0.7554390822301416 and parameters: {'score_th': 0.0183676176261529, 'distance': 47}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:38,353] Trial 70 finished with value: 0.75742925558217 and parameters: {'score_th': 0.011498885978536353, 'distance': 77}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:43,084] Trial 71 finished with value: 0.758748659944293 and parameters: {'score_th': 0.0042258304943673134, 'distance': 57}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:47,259] Trial 72 finished with value: 0.7584909100939958 and parameters: {'score_th': 0.006723468441464956, 'distance': 66}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:52,449] Trial 73 finished with value: 0.7592703930281768 and parameters: {'score_th': 0.0030544076525759693, 'distance': 60}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:20:57,846] Trial 74 finished with value: 0.7586367066466515 and parameters: {'score_th': 0.0029176704204419554, 'distance': 52}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:01,361] Trial 75 finished with value: 0.7490984113551103 and parameters: {'score_th': 0.008363168997480989, 'distance': 189}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:10,704] Trial 76 finished with value: 0.7577353771056956 and parameters: {'score_th': 0.0011387147225014277, 'distance': 43}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:14,345] Trial 77 finished with value: 0.7563499110629452 and parameters: {'score_th': 0.01579468418909339, 'distance': 73}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:18,360] Trial 78 finished with value: 0.7583212648767685 and parameters: {'score_th': 0.00684769694565603, 'distance': 93}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:22,049] Trial 79 finished with value: 0.756337126101426 and parameters: {'score_th': 0.01137493749312382, 'distance': 112}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:26,269] Trial 80 finished with value: 0.7586036015082758 and parameters: {'score_th': 0.005767731246795512, 'distance': 58}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:31,612] Trial 81 finished with value: 0.7592615770494602 and parameters: {'score_th': 0.0026759064920445236, 'distance': 65}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:36,736] Trial 82 finished with value: 0.7591927695661072 and parameters: {'score_th': 0.0031119407531859287, 'distance': 65}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:41,090] Trial 83 finished with value: 0.755056830870855 and parameters: {'score_th': 0.009393034984425699, 'distance': 32}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:48,859] Trial 84 finished with value: 0.7593216379379764 and parameters: {'score_th': 0.0010340940570915894, 'distance': 80}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:56,019] Trial 85 finished with value: 0.7593143350997615 and parameters: {'score_th': 0.0011237430690551533, 'distance': 82}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:21:59,690] Trial 86 finished with value: 0.7565668811991388 and parameters: {'score_th': 0.013606686322635637, 'distance': 81}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:06,315] Trial 87 finished with value: 0.7593065068818219 and parameters: {'score_th': 0.0012014609084778222, 'distance': 97}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:10,270] Trial 88 finished with value: 0.758253051522288 and parameters: {'score_th': 0.006860065354667576, 'distance': 99}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:15,091] Trial 89 finished with value: 0.7588426450472818 and parameters: {'score_th': 0.0029808153683028604, 'distance': 87}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:18,754] Trial 90 finished with value: 0.7576234601640539 and parameters: {'score_th': 0.009035178753159411, 'distance': 104}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:24,650] Trial 91 finished with value: 0.7592164908618687 and parameters: {'score_th': 0.0016791349764728944, 'distance': 91}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:28,744] Trial 92 finished with value: 0.7583081420069095 and parameters: {'score_th': 0.0063078765868657925, 'distance': 96}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:33,718] Trial 93 finished with value: 0.7594130643944595 and parameters: {'score_th': 0.003011680637246537, 'distance': 79}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:38,370] Trial 94 finished with value: 0.7590927965075629 and parameters: {'score_th': 0.0032938386281942417, 'distance': 83}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:42,018] Trial 95 finished with value: 0.7551902816755924 and parameters: {'score_th': 0.01112963810104482, 'distance': 119}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:46,336] Trial 96 finished with value: 0.7590493621801864 and parameters: {'score_th': 0.005151357447813434, 'distance': 79}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:54,265] Trial 97 finished with value: 0.7592824496963455 and parameters: {'score_th': 0.0010555475526617141, 'distance': 73}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:22:58,263] Trial 98 finished with value: 0.7579238300788853 and parameters: {'score_th': 0.008626963787192361, 'distance': 74}. Best is trial 31 with value: 0.7595136568574408.
# [I 2023-11-26 01:23:07,101] Trial 99 finished with value: 0.759606523625776 and parameters: {'score_th': 0.0010367671953843134, 'distance': 68}. Best is trial 99 with value: 0.759606523625776.
# {'score_th': 0.0010367671953843134, 'distance': 68}

# %%
def plot_random_sample(keys, preds, labels, num_samples=1, num_chunks=10):
    # get series ids
    series_ids = np.array(list(map(lambda x: x.split("_")[0], keys)))
    unique_series_ids = np.unique(series_ids)

    # get random series
    random_series_ids = np.random.choice(unique_series_ids, num_samples)

    for i, random_series_id in enumerate(random_series_ids):
        # get random series
        series_idx = np.where(series_ids == random_series_id)[0]
        # this_series_preds = preds[series_idx].reshape(-1, 3)
        # this_series_labels = labels[series_idx].reshape(-1, 3)
        this_series_preds = preds[series_idx].reshape(-1, 2)
        this_series_labels = labels[series_idx].reshape(-1, 2)

        # split series
        this_series_preds = np.split(this_series_preds, num_chunks)
        this_series_labels = np.split(this_series_labels, num_chunks)

        fig, axs = plt.subplots(num_chunks, 1, figsize=(20, 5 * num_chunks))
        if num_chunks == 1:
            axs = [axs]
        for j in range(num_chunks):
            this_series_preds_chunk = this_series_preds[j]
            this_series_labels_chunk = this_series_labels[j]

            # get onset and wakeup idx
            onset_idx = np.nonzero(this_series_labels_chunk[:, 0])[0]
            wakeup_idx = np.nonzero(this_series_labels_chunk[:, 1])[0]

            # axs[j].plot(this_series_preds_chunk[:, 0], label="pred_sleep")
            axs[j].plot(this_series_preds_chunk[:, 0], label="pred_onset")
            axs[j].plot(this_series_preds_chunk[:, 1], label="pred_wakeup")
            axs[j].vlines(
                onset_idx, 0, 1, label="onset", linestyles="dashed", color="orange", alpha=0.5
            )
            axs[j].vlines(
                wakeup_idx, 0, 1, label="wakeup", linestyles="dashed", color="green", alpha=0.5
            )
            axs[j].set_ylim(0, 1)
            axs[j].set_title(f"series_id: {random_series_id} chunk_id: {j}")
            axs[j].legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0)

    plt.tight_layout()

# %%
plot_random_sample(keys, preds, labels, num_chunks=10)
