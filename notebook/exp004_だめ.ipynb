# %%
import pandas as pd
import torch
from pathlib import Path
from hydra import initialize, compose
from hydra.core.global_hydra import GlobalHydra
from src.utils.metrics import event_detection_ap

from src.utils.post_process import post_process_for_seg
import jupyter_black
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import optuna


jupyter_black.load()
plt.style.use("ggplot")

EXP_NAME = "exp004"
RUN_NAME = "single"
RESULT_DIR = Path("../output/train") / EXP_NAME / RUN_NAME


def load_config(result_dir: Path):
    # clear previous initialization
    GlobalHydra.instance().clear()

    # initialize hydra
    config_path = result_dir / ".hydra"
    initialize(config_path=config_path.as_posix())
    # load the config
    cfg = compose(config_name="config")

    return cfg
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
cfg = load_config(RESULT_DIR)
preds = np.load(RESULT_DIR / "preds.npy")
labels = np.load(RESULT_DIR / "labels.npy")
keys = np.load(RESULT_DIR / "keys.npy")

gt_df = pd.read_csv(Path(cfg.dir.data_dir) / "train_events.csv")
gt_df = gt_df[gt_df["series_id"].isin(cfg.split.valid_series_ids)].dropna().reset_index(drop=True)
# Out:
# /tmp/ipykernel_1332010/136570854.py:31: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   initialize(config_path=config_path.as_posix())
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 cfg = load_config(RESULT_DIR)
# ----> 2 preds = np.load(RESULT_DIR / "preds.npy")
#       3 labels = np.load(RESULT_DIR / "labels.npy")
#       4 keys = np.load(RESULT_DIR / "keys.npy")
#
# File ~/kaggle-child-mind-institute-detect-sleep-states/.venv/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/train/exp004/single/preds.npy'

# %%
def objective(trial: optuna.Trial):
    score_th = trial.suggest_float("score_th", 0.001, 0.1)
    distance = trial.suggest_int("distance", 1, 200)

    # pred_df: pl.DataFrame = post_process_for_seg(
    #     keys, preds[:, :, [1, 2]], score_th=score_th, distance=distance
    # )
    pred_df: pl.DataFrame = post_process_for_seg(keys, preds, score_th=score_th, distance=distance)
    score = event_detection_ap(gt_df, pred_df.to_pandas())

    return score


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print(study.best_params)
# Out:
# [I 2023-11-24 09:50:27,968] A new study created in memory with name: no-name-c58f1d75-2e0a-4d83-917d-b578b25f7cb6
# [I 2023-11-24 09:50:31,759] Trial 0 finished with value: 0.6924978030801394 and parameters: {'score_th': 0.07470550155608853, 'distance': 22}. Best is trial 0 with value: 0.6924978030801394.
# [I 2023-11-24 09:50:35,699] Trial 1 finished with value: 0.7099943349129137 and parameters: {'score_th': 0.017835183327614905, 'distance': 114}. Best is trial 1 with value: 0.7099943349129137.
# [I 2023-11-24 09:50:40,863] Trial 2 finished with value: 0.6902164973324544 and parameters: {'score_th': 0.013019144349307028, 'distance': 8}. Best is trial 1 with value: 0.7099943349129137.
# [I 2023-11-24 09:50:44,440] Trial 3 finished with value: 0.6952923954985233 and parameters: {'score_th': 0.051790591063993044, 'distance': 189}. Best is trial 1 with value: 0.7099943349129137.
# [I 2023-11-24 09:50:51,759] Trial 4 finished with value: 0.7122811959177202 and parameters: {'score_th': 0.0017965747455050895, 'distance': 119}. Best is trial 4 with value: 0.7122811959177202.
# [I 2023-11-24 09:52:10,160] Trial 20 finished with value: 0.7085868122814418 and parameters: {'score_th': 0.0014422055444387057, 'distance': 166}. Best is trial 15 with value: 0.7127264388801102.
# [I 2023-11-24 09:52:14,783] Trial 21 finished with value: 0.711288322303541 and parameters: {'score_th': 0.009171628410205019, 'distance': 76}. Best is trial 15 with value: 0.7127264388801102.
# [I 2023-11-24 09:52:19,414] Trial 22 finished with value: 0.7076438043236666 and parameters: {'score_th': 0.011044767307998637, 'distance': 45}. Best is trial 15 with value: 0.7127264388801102.
# [I 2023-11-24 09:52:26,754] Trial 23 finished with value: 0.7130131103356707 and parameters: {'score_th': 0.0020007687945643713, 'distance': 102}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:30,603] Trial 24 finished with value: 0.7094603116513631 and parameters: {'score_th': 0.021147333926864596, 'distance': 107}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:34,609] Trial 25 finished with value: 0.7095071217383551 and parameters: {'score_th': 0.010683510311866332, 'distance': 135}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:38,460] Trial 26 finished with value: 0.7087399087556986 and parameters: {'score_th': 0.02062814892949885, 'distance': 119}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:43,225] Trial 27 finished with value: 0.7110668526729169 and parameters: {'score_th': 0.007522673921018868, 'distance': 92}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:46,927] Trial 28 finished with value: 0.7074104731830244 and parameters: {'score_th': 0.029369525939374846, 'distance': 103}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:51,327] Trial 29 finished with value: 0.7054126360618227 and parameters: {'score_th': 0.013498714706152468, 'distance': 31}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:52:55,730] Trial 30 finished with value: 0.7077470416637088 and parameters: {'score_th': 0.006909742458548182, 'distance': 162}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:03,918] Trial 31 finished with value: 0.7124941635579669 and parameters: {'score_th': 0.0017005974093504672, 'distance': 76}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:10,219] Trial 32 finished with value: 0.7128209943096214 and parameters: {'score_th': 0.002589209604519742, 'distance': 112}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:14,074] Trial 33 finished with value: 0.7094957935277637 and parameters: {'score_th': 0.019062273303135223, 'distance': 81}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:18,177] Trial 34 finished with value: 0.7111233970441326 and parameters: {'score_th': 0.011441291254452677, 'distance': 109}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:22,305] Trial 35 finished with value: 0.7090164664009984 and parameters: {'score_th': 0.015921088947190742, 'distance': 63}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:27,569] Trial 36 finished with value: 0.7120249991845793 and parameters: {'score_th': 0.004965611393650623, 'distance': 94}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:31,760] Trial 37 finished with value: 0.7073226637621572 and parameters: {'score_th': 0.014341472900855294, 'distance': 47}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:38,817] Trial 38 finished with value: 0.7112755530118584 and parameters: {'score_th': 0.0015311730347416924, 'distance': 135}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:42,539] Trial 39 finished with value: 0.7084724195298726 and parameters: {'score_th': 0.024501709356900193, 'distance': 84}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:47,220] Trial 40 finished with value: 0.7116399695479971 and parameters: {'score_th': 0.006762886234020281, 'distance': 116}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:53:52,174] Trial 41 finished with value: 0.7119314163063517 and parameters: {'score_th': 0.006232492418713665, 'distance': 97}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:54:00,523] Trial 42 finished with value: 0.7126720434639747 and parameters: {'score_th': 0.0011512088424749892, 'distance': 115}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09
. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:58:46,315] Trial 92 finished with value: 0.7066147408998376 and parameters: {'score_th': 0.0013182721927029067, 'distance': 198}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:58:51,085] Trial 93 finished with value: 0.7119202543411336 and parameters: {'score_th': 0.005574905459547119, 'distance': 81}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:58:55,565] Trial 94 finished with value: 0.711192828920318 and parameters: {'score_th': 0.008005266447403635, 'distance': 73}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:59:03,810] Trial 95 finished with value: 0.7024599174078139 and parameters: {'score_th': 0.004308231368865474, 'distance': 16}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:59:07,865] Trial 96 finished with value: 0.7106366631380798 and parameters: {'score_th': 0.00981597987405281, 'distance': 118}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:59:16,482] Trial 97 finished with value: 0.7129419915525192 and parameters: {'score_th': 0.0010899653905977365, 'distance': 100}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:59:20,298] Trial 98 finished with value: 0.7104486736840925 and parameters: {'score_th': 0.014691311357780403, 'distance': 111}. Best is trial 23 with value: 0.7130131103356707.
# [I 2023-11-24 09:59:24,853] Trial 99 finished with value: 0.7119326587495389 and parameters: {'score_th': 0.006030569732872974, 'distance': 99}. Best is trial 23 with value: 0.7130131103356707.
# {'score_th': 0.0020007687945643713, 'distance': 102}

# %%
def plot_random_sample(keys, preds, labels, num_samples=1, num_chunks=10):
    # get series ids
    series_ids = np.array(list(map(lambda x: x.split("_")[0], keys)))
    unique_series_ids = np.unique(series_ids)

    # get random series
    random_series_ids = np.random.choice(unique_series_ids, num_samples)

    for i, random_series_id in enumerate(random_series_ids):
        # get random series
        series_idx = np.where(series_ids == random_series_id)[0]
        # this_series_preds = preds[series_idx].reshape(-1, 3)
        # this_series_labels = labels[series_idx].reshape(-1, 3)
        this_series_preds = preds[series_idx].reshape(-1, 2)
        this_series_labels = labels[series_idx].reshape(-1, 2)

        # split series
        this_series_preds = np.split(this_series_preds, num_chunks)
        this_series_labels = np.split(this_series_labels, num_chunks)

        fig, axs = plt.subplots(num_chunks, 1, figsize=(20, 5 * num_chunks))
        if num_chunks == 1:
            axs = [axs]
        for j in range(num_chunks):
            this_series_preds_chunk = this_series_preds[j]
            this_series_labels_chunk = this_series_labels[j]

            # get onset and wakeup idx
            onset_idx = np.nonzero(this_series_labels_chunk[:, 0])[0]
            wakeup_idx = np.nonzero(this_series_labels_chunk[:, 1])[0]

            # axs[j].plot(this_series_preds_chunk[:, 0], label="pred_sleep")
            axs[j].plot(this_series_preds_chunk[:, 0], label="pred_onset")
            axs[j].plot(this_series_preds_chunk[:, 1], label="pred_wakeup")
            axs[j].vlines(
                onset_idx, 0, 1, label="onset", linestyles="dashed", color="orange", alpha=0.5
            )
            axs[j].vlines(
                wakeup_idx, 0, 1, label="wakeup", linestyles="dashed", color="green", alpha=0.5
            )
            axs[j].set_ylim(0, 1)
            axs[j].set_title(f"series_id: {random_series_id} chunk_id: {j}")
            axs[j].legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0)

    plt.tight_layout()

# %%
plot_random_sample(keys, preds, labels, num_chunks=10)
