# %%
import pandas as pd
import torch
from pathlib import Path
from hydra import initialize, compose
from hydra.core.global_hydra import GlobalHydra
from src.utils.metrics import event_detection_ap

from src.utils.post_process import post_process_for_seg
import jupyter_black
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import optuna


jupyter_black.load()
plt.style.use("ggplot")

EXP_NAME = "exp008_diffAnglez"
RUN_NAME = "single"
RESULT_DIR = Path("../output/train") / EXP_NAME / RUN_NAME


def load_config(result_dir: Path):
    # clear previous initialization
    GlobalHydra.instance().clear()

    # initialize hydra
    config_path = result_dir / ".hydra"
    initialize(config_path=config_path.as_posix())
    # load the config
    cfg = compose(config_name="config")

    return cfg

# %%
cfg = load_config(RESULT_DIR)
preds = np.load(RESULT_DIR / "preds_fold_0.npy")
labels = np.load(RESULT_DIR / "labels_fold_0.npy")
keys = np.load(RESULT_DIR / "keys_fold_0.npy")

gt_df = pd.read_csv(Path(cfg.dir.data_dir) / "train_events.csv")
gt_df = gt_df[gt_df["series_id"].isin(cfg.split.valid_series_ids)].dropna().reset_index(drop=True)
# Out:
# /tmp/ipykernel_404849/1400671780.py:31: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   initialize(config_path=config_path.as_posix())

# %%
def objective(trial: optuna.Trial):
    score_th = trial.suggest_float("score_th", 0.0005, 0.1)
    distance = trial.suggest_int("distance", 20, 200)

    # pred_df: pl.DataFrame = post_process_for_seg(
    #     keys, preds[:, :, [1, 2]], score_th=score_th, distance=distance
    # )
    pred_df: pl.DataFrame = post_process_for_seg(keys, preds, score_th=score_th, distance=distance)
    score = event_detection_ap(gt_df, pred_df.to_pandas())

    return score


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print(study.best_params)
# Out:
# [I 2023-11-26 07:22:58,867] A new study created in memory with name: no-name-59e6e95a-c32b-4d7e-8b8a-ceae78dfdca3
# [I 2023-11-26 07:23:02,363] Trial 0 finished with value: 0.7469077775363882 and parameters: {'score_th': 0.049659538897768966, 'distance': 67}. Best is trial 0 with value: 0.7469077775363882.
# [I 2023-11-26 07:23:05,480] Trial 1 finished with value: 0.7420662486285299 and parameters: {'score_th': 0.06049681486228369, 'distance': 120}. Best is trial 0 with value: 0.7469077775363882.
# [I 2023-11-26 07:23:08,749] Trial 2 finished with value: 0.7399246135268591 and parameters: {'score_th': 0.06634118595444084, 'distance': 130}. Best is trial 0 with value: 0.7469077775363882.
# [I 2023-11-26 07:23:12,090] Trial 3 finished with value: 0.7428321183183295 and parameters: {'score_th': 0.07375340360957877, 'distance': 42}. Best is trial 0 with value: 0.7469077775363882.
# [I 2023-11-26 07:23:15,781] Trial 4 finished with value: 0.7523907481692713 and parameters: {'score_th': 0.014581845800481361, 'distance': 114}. Best is trial 4 with value: 0.7523907481692713.
# [I 2023-11-26 07:23:18,990] Trial 5 finished with value: 0.7298203939889311 and parameters: {'score_th': 0.09144076674834495, 'distance': 174}. Best is trial 4 with value: 0.7523907481692713.
# [I 2023-11-26 07:23:22,336] Trial 6 finished with value: 0.7484316059365449 and parameters: {'score_th': 0.04015243768894266, 'distance': 28}. Best is trial 4 with value: 0.7523907481692713.
# [I 2023-11-26 07:23:26,017] Trial 7 finished with value: 0.7528684265822823 and parameters: {'score_th': 0.01852247935670956, 'distance': 74}. Best is trial 7 with value: 0.7528684265822823.
# [I 2023-11-26 07:23:29,320] Trial 8 finished with value: 0.7343387849727194 and parameters: {'score_th': 0.06218251861474493, 'distance': 191}. Best is trial 7 with value: 0.7528684265822823.
# [I 2023-11-26 07:23:32,668] Trial 9 finished with value: 0.741294496834144 and parameters: {'score_th': 0.046586847031903876, 'distance': 162}. Best is trial 7 with value: 0.7528684265822823.
# [I 2023-11-26 07:23:36,571] Trial 10 finished with value: 0.7549580545413286 and parameters: {'score_th': 0.00929220485725538, 'distance': 73}. Best is trial 10 with value: 0.7549580545413286.
# [I 2023-11-26 07:23:43,260] Trial 11 finished with value: 0.7561393451336491 and parameters: {'score_th': 0.0016428889594256417, 'distance': 76}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:23:48,560] Trial 12 finished with value: 0.7556502069262636 and parameters: {'score_th': 0.0033280301266174336, 'distance': 79}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:23:53,976] Trial 13 finished with value: 0.7555292900062764 and parameters: {'score_th': 0.0024364524754320206, 'distance': 88}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:23:57,552] Trial 14 finished with value: 0.7513849078082269 and parameters: {'score_th': 0.028979849940590066, 'distance': 51}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:03,396] Trial 15 finished with value: 0.7554643177556909 and parameters: {'score_th': 0.0017841962576091077, 'distance': 92}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:06,742] Trial 16 finished with value: 0.7479488774303382 and parameters: {'score_th': 0.02613614784794053, 'distance': 143}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:10,206] Trial 17 finished with value: 0.7510487419088903 and parameters: {'score_th': 0.02405120587844967, 'distance': 96}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:14,275] Trial 18 finished with value: 0.754695422502077 and parameters: {'score_th': 0.01043895741163766, 'distance': 54}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:37,186] Trial 19 finished with value: 0.7531143744340048 and parameters: {'score_th': 0.0006684926017742261, 'distance': 22}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:40,419] Trial 20 finished with value: 0.7489088719995105 and parameters: {'score_th': 0.035398947601058314, 'distance': 96}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:46,692] Trial 21 finished with value: 0.7557408085612392 and parameters: {'score_th': 0.0016531708677258187, 'distance': 86}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:50,370] Trial 22 finished with value: 0.7532359109304019 and parameters: {'score_th': 0.01673236195913463, 'distance': 76}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:54,338] Trial 23 finished with value: 0.754593230710342 and parameters: {'score_th': 0.008369956056284395, 'distance': 102}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:24:58,073] Trial 24 finished with value: 0.7527105067123985 and parameters: {'score_th': 0.020020767994023175, 'distance': 44}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:02,068] Trial 25 finished with value: 0.7549269270070482 and parameters: {'score_th': 0.00916115817934273, 'distance': 60}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:05,430] Trial 26 finished with value: 0.7489683457589738 and parameters: {'score_th': 0.028335412564687964, 'distance': 124}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:15,012] Trial 27 finished with value: 0.7559861525072255 and parameters: {'score_th': 0.0007963567079661804, 'distance': 83}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:18,582] Trial 28 finished with value: 0.7517942293683638 and parameters: {'score_th': 0.01233496486258031, 'distance': 138}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:22,306] Trial 29 finished with value: 0.7527123920787143 and parameters: {'score_th': 0.020108086274570038, 'distance': 65}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:26,224] Trial 30 finished with value: 0.7547364365341893 and parameters: {'score_th': 0.006387749195389584, 'distance': 106}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:33,924] Trial 31 finished with value: 0.7559056574448795 and parameters: {'score_th': 0.001072653371109297, 'distance': 89}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:42,714] Trial 32 finished with value: 0.7559324278297284 and parameters: {'score_th': 0.0009048542759280257, 'distance': 84}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07:25:46,550] Trial 33 finished with value: 0.7541898044404794 and parameters: {'score_th': 0.012650430517200698, 'distance': 65}. Best is trial 11 with value: 0.7561393451336491.
# [I 2023-11-26 07
. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:07,603] Trial 89 finished with value: 0.7553072327341294 and parameters: {'score_th': 0.005171543485979738, 'distance': 58}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:11,282] Trial 90 finished with value: 0.7542749997089606 and parameters: {'score_th': 0.011332809601356141, 'distance': 80}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:23,319] Trial 91 finished with value: 0.7559861486001649 and parameters: {'score_th': 0.0005539136001790657, 'distance': 91}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:33,542] Trial 92 finished with value: 0.7559396731181511 and parameters: {'score_th': 0.00071945053455013, 'distance': 88}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:38,364] Trial 93 finished with value: 0.755390293706091 and parameters: {'score_th': 0.003421302982212919, 'distance': 103}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:43,743] Trial 94 finished with value: 0.7557831341906152 and parameters: {'score_th': 0.002702754951239534, 'distance': 66}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:48,097] Trial 95 finished with value: 0.7550906481860447 and parameters: {'score_th': 0.00658367830641392, 'distance': 72}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:52,495] Trial 96 finished with value: 0.7547981815568352 and parameters: {'score_th': 0.005692343519001562, 'distance': 93}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:31:56,333] Trial 97 finished with value: 0.7543859240344237 and parameters: {'score_th': 0.008819967199947668, 'distance': 110}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:32:06,027] Trial 98 finished with value: 0.7560873008768159 and parameters: {'score_th': 0.0007258315330492422, 'distance': 98}. Best is trial 52 with value: 0.7561394800524748.
# [I 2023-11-26 07:32:10,725] Trial 99 finished with value: 0.754235896446225 and parameters: {'score_th': 0.0024525966373893093, 'distance': 134}. Best is trial 52 with value: 0.7561394800524748.
# {'score_th': 0.0005702263928310481, 'distance': 72}

# %%
def plot_random_sample(keys, preds, labels, num_samples=1, num_chunks=10):
    # get series ids
    series_ids = np.array(list(map(lambda x: x.split("_")[0], keys)))
    unique_series_ids = np.unique(series_ids)

    # get random series
    random_series_ids = np.random.choice(unique_series_ids, num_samples)

    for i, random_series_id in enumerate(random_series_ids):
        # get random series
        series_idx = np.where(series_ids == random_series_id)[0]
        # this_series_preds = preds[series_idx].reshape(-1, 3)
        # this_series_labels = labels[series_idx].reshape(-1, 3)
        this_series_preds = preds[series_idx].reshape(-1, 2)
        this_series_labels = labels[series_idx].reshape(-1, 2)

        # split series
        this_series_preds = np.split(this_series_preds, num_chunks)
        this_series_labels = np.split(this_series_labels, num_chunks)

        fig, axs = plt.subplots(num_chunks, 1, figsize=(20, 5 * num_chunks))
        if num_chunks == 1:
            axs = [axs]
        for j in range(num_chunks):
            this_series_preds_chunk = this_series_preds[j]
            this_series_labels_chunk = this_series_labels[j]

            # get onset and wakeup idx
            onset_idx = np.nonzero(this_series_labels_chunk[:, 0])[0]
            wakeup_idx = np.nonzero(this_series_labels_chunk[:, 1])[0]

            # axs[j].plot(this_series_preds_chunk[:, 0], label="pred_sleep")
            axs[j].plot(this_series_preds_chunk[:, 0], label="pred_onset")
            axs[j].plot(this_series_preds_chunk[:, 1], label="pred_wakeup")
            axs[j].vlines(
                onset_idx, 0, 1, label="onset", linestyles="dashed", color="orange", alpha=0.5
            )
            axs[j].vlines(
                wakeup_idx, 0, 1, label="wakeup", linestyles="dashed", color="green", alpha=0.5
            )
            axs[j].set_ylim(0, 1)
            axs[j].set_title(f"series_id: {random_series_id} chunk_id: {j}")
            axs[j].legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0)

    plt.tight_layout()

# %%
plot_random_sample(keys, preds, labels, num_chunks=10)
